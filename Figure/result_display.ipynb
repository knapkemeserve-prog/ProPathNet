# %%
#fig2a
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig2a.py

# %%
#fig2b
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig2b.py

# %%
#fig2c
source("/home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig2c.r")
# Out:
# [1] "\n包含完美对齐、2行物理换行和行高优化的森林图已保存到: /home/xuln/olink_disease_predict/ProPathNet-github/Figure/forest_results.png"
# plot without title

# %%
#fig3a
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig3a.py
# Out:
# ...
# 开始绘制 Cancers 疾病 Olink 蛋白特征全景图...
# 📊 统计报告: 横轴共展示了 116 个蛋白。
# 📊 报告: 其中前 15 个蛋白被包含在虚线框(top_n)中。

# %%
#fig3b
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig3b.py
# Out:
# ...
# 开始极速绘制 Cancers 疾病临床特征全景图...
# 共有特征数量: 96

# %%
#fig3c
source('/home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig3c-pathway.r')
# Out:
# plot without title

# %%
#fig4a
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig4a.py

# %%
#fig4bc
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig4bc.py
# Out:
# 1x4 ROC曲线图已保存至: /home/xuln/olink_disease_predict/ProPathNet-github/result/3models_ROC_1x4_Primary_Malignancy_Prostate.png
# 1x4 PRC曲线图已保存至: /home/xuln/olink_disease_predict/ProPathNet-github/result/3models_PRC_1x4_Primary_Malignancy_Prostate.png
#
# ...
# 各模型在全部时间点（0, 3, 5, 10年）的综合评估指标：
# ...
# Time_Point                      Model      AUC  C-index    AUPRC  Best_F1  Precision   Recall
#     0-Year                     Clinic 0.799799      NaN 0.046832 0.106870   0.076923 0.175000
#     0-Year  Clinic+Lifestyle-opt-pred 0.791169      NaN 0.045846 0.091954   0.085106 0.100000
#     0-Year Clinic+ProPathNet-opt-pred 0.915312      NaN 0.176991 0.300000   0.210000 0.525000
#     3-Year                     Clinic 0.734232 0.735175 0.013577 0.038835   0.025316 0.083333
#     3-Year       Clinic+Lifestyle-opt 0.738591 0.739336 0.013799 0.037870   0.019488 0.666667
#     3-Year      Clinic+ProPathNet-opt 0.850830 0.850890 0.070443 0.137500   0.080882 0.458333
# ...

# %%
#fig5
source('/home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig5.r')
# Out:
# plot without title

# %%
#fig6
# %matplotlib inline
# %run /home/xuln/olink_disease_predict/ProPathNet-github/Figure/fig6.py
# Out:
# 已在汇总表中找到 'Primary Malignancy Prostate'，使用的最佳蛋白数量为: 19
#
# 成功提取出前 19 个靶蛋白，数据预览：
#     protein  importance
# 0      KLK3    1.137684
# 1  SERPINE1    0.133399
# 2      MYH9    0.099104
# 3  PNLIPRP2    0.090032
# 4     PAPPA    0.074377
